# %% [markdown]
# <a href="https://colab.research.google.com/github/Meridor6919/BeeClassification/blob/master/LowDropout.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import keras
from keras import layers
import tensorflow as tf
import tensorflow_datasets as tfds
import numpy as np
from tensorflow.keras import datasets, layers, models, losses
import matplotlib.pyplot as plt

# %%
dataset = tfds.load('bee_dataset', split=['train'], as_supervised=True)
# Out:
# Downloading and preparing dataset 192.39 MiB (download: 192.39 MiB, generated: 97.96 MiB, total: 290.35 MiB) to ~/tensorflow_datasets/bee_dataset/bee_dataset_300/1.0.0...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# Extraction completed...: 0 file [00:00, ? file/s]
# Generating splits...:   0%|          | 0/1 [00:00<?, ? splits/s]
# Generating train examples...:   0%|          | 0/7490 [00:00<?, ? examples/s]
# Shuffling ~/tensorflow_datasets/bee_dataset/bee_dataset_300/1.0.0.incompleteCNC0CH/bee_dataset-train.tfrecord*…
# Dataset bee_dataset downloaded and prepared to ~/tensorflow_datasets/bee_dataset/bee_dataset_300/1.0.0. Subsequent calls will reuse this data.

# %%
#Split between training data, validation data, test data
splitSize = (0.0, 0.765, 0.9, 1.0)

# %% [markdown]
# Testing precision on red channel only

# %%
array = np.vstack(tfds.as_numpy(dataset[0]))
ranges = list([int(array.shape[0] * x) for x in splitSize])

def getDataset(ranges, idx):
    return (
        np.array(list(map(lambda x: x[0][:, :, :], array[ranges[idx]: ranges[idx + 1]]))),
        np.array(list(map(lambda x: x[1]['varroa_output'], array[ranges[idx]: ranges[idx + 1]]))),
        np.array(list(map(lambda x: x[1]['pollen_output'], array[ranges[idx]: ranges[idx + 1]]))),
        np.array(list(map(lambda x: x[1]['wasps_output'], array[ranges[idx]: ranges[idx + 1]]))),
        np.array(list(map(lambda x: x[1]['cooling_output'], array[ranges[idx]: ranges[idx + 1]])))
    )
train_images, train_labels1,train_labels2,train_labels3, train_labels4= getDataset(ranges, 0)
validation_images, validation_labels1,validation_labels2, validation_labels3, validation_labels4 = getDataset(ranges, 1)
test_images, test_labels1,test_labels2,test_labels3, test_labels4  = getDataset(ranges, 2)
# Out:
# <ipython-input-4-e43ac078c997>:1: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   array = np.vstack(tfds.as_numpy(dataset[0]))
# /usr/local/lib/python3.8/dist-packages/numpy/core/shape_base.py:121: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   ary = asanyarray(ary)

# %%
train_labels = np.dstack((train_labels1, train_labels2, train_labels3,train_labels4)).squeeze()
validation_labels = np.dstack((validation_labels1,validation_labels2, validation_labels3, validation_labels4)).squeeze()
test_labels = np.dstack((test_labels1,test_labels2,test_labels3, test_labels4)).squeeze()

# %%
class my_metric:
  binaryAcc = tf.keras.metrics.BinaryAccuracy(threshold=0.9)

  def all(y_true, y_pred):
    my_metric.binaryAcc.reset_state()
    my_metric.binaryAcc.update_state(y_true, y_pred)
    return my_metric.binaryAcc.result()

  def varroa(y_true, y_pred):
    my_metric.binaryAcc.reset_state()
    my_metric.binaryAcc.update_state(y_true[:, 0], y_pred[:, 0])
    return my_metric.binaryAcc.result()

  def pollen(y_true, y_pred):
    my_metric.binaryAcc.reset_state()
    my_metric.binaryAcc.update_state(y_true[:, 1], y_pred[:, 1])
    return my_metric.binaryAcc.result()

  def wasps(y_true, y_pred):
    my_metric.binaryAcc.reset_state()
    my_metric.binaryAcc.update_state(y_true[:, 2], y_pred[:, 2])
    return my_metric.binaryAcc.result()

  def cooling(y_true, y_pred):
    my_metric.binaryAcc.reset_state()
    my_metric.binaryAcc.update_state(y_true[:, 3], y_pred[:, 3])
    return my_metric.binaryAcc.result()

# %%
import datetime
import tensorflow_hub as hub
def create_tensorboard_callback(dir_name, experiment_name):
  log_dir = dir_name + "/" + experiment_name + "/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
  tensorboard_callback = tf.keras.callbacks.TensorBoard(
      log_dir=log_dir
  )
  print(log_dir)
  return tensorboard_callback

# %%
model= tf.keras.models.Sequential([
  tf.keras.layers.Conv2D(filters=10, 
                         kernel_size=3, 
                         activation="relu", 
                         input_shape=(300, 150, 3)), 
  tf.keras.layers.Conv2D(10, 3, activation="relu"),
  tf.keras.layers.MaxPool2D(pool_size=2, 
                            padding="valid"), 
  tf.keras.layers.Conv2D(10, 3, activation="relu"),
  tf.keras.layers.Conv2D(10, 3, activation="relu"), 

  tf.keras.layers.MaxPool2D(2),
  tf.keras.layers.Flatten(),
  tf.keras.layers.Dropout(0.2),
  tf.keras.layers.Dense(4, activation="sigmoid") 
])

model.compile(loss="binary_crossentropy",
              optimizer=tf.keras.optimizers.Adam(),
              metrics=[my_metric.all, my_metric.varroa, my_metric.pollen, my_metric.wasps, my_metric.cooling,])

history = model.fit(train_images, train_labels,
                        epochs=20,
                        batch_size = 32,
                        callbacks = create_tensorboard_callback(dir_name="tensorflow_hub", 
                                                                                     experiment_name="model"),
                        validation_data=(validation_images, validation_labels))
# Out:
# tensorflow_hub/model/20230110-132839
# Epoch 1/20
# 180/180 [==============================] - 8s 42ms/step - loss: 0.6016 - all: 0.8838 - varroa: 0.8257 - pollen: 0.8623 - wasps: 0.9380 - cooling: 0.9090 - val_loss: 0.1825 - val_all: 0.9110 - val_varroa: 0.8291 - val_pollen: 0.8547 - val_wasps: 0.9941 - val_cooling: 0.9662
# Epoch 2/20
# 180/180 [==============================] - 7s 39ms/step - loss: 0.1365 - all: 0.9233 - varroa: 0.8455 - pollen: 0.8929 - wasps: 0.9934 - cooling: 0.9613 - val_loss: 0.1596 - val_all: 0.9197 - val_varroa: 0.8330 - val_pollen: 0.8699 - val_wasps: 0.9961 - val_cooling: 0.9799
# Epoch 3/20
# 180/180 [==============================] - 7s 41ms/step - loss: 0.0931 - all: 0.9406 - varroa: 0.8686 - pollen: 0.9172 - wasps: 0.9977 - cooling: 0.9788 - val_loss: 0.1783 - val_all: 0.9174 - val_varroa: 0.8516 - val_pollen: 0.8803 - val_wasps: 0.9951 - val_cooling: 0.9426
# Epoch 4/20
# 180/180 [==============================] - 7s 41ms/step - loss: 0.0773 - all: 0.9486 - varroa: 0.8910 - pollen: 0.9281 - wasps: 0.9970 - cooling: 0.9781 - val_loss: 0.1641 - val_all: 0.9350 - val_varroa: 0.8652 - val_pollen: 0.9051 - val_wasps: 0.9961 - val_cooling: 0.9734
# Epoch 5/20
# 180/180 [==============================] - 8s 42ms/step - loss: 0.0518 - all: 0.9631 - varroa: 0.9168 - pollen: 0.9460 - wasps: 0.9990 - cooling: 0.9906 - val_loss: 0.1718 - val_all: 0.9415 - val_varroa: 0.8662 - val_pollen: 0.9207 - val_wasps: 0.9941 - val_cooling: 0.9848
# Epoch 6/20
# 180/180 [==============================] - 8s 42ms/step - loss: 0.0403 - all: 0.9716 - varroa: 0.9321 - pollen: 0.9618 - wasps: 0.9993 - cooling: 0.9931 - val_loss: 0.1710 - val_all: 0.9392 - val_varroa: 0.8662 - val_pollen: 0.9096 - val_wasps: 0.9971 - val_cooling: 0.9838
# Epoch 7/20
# 180/180 [==============================] - 7s 42ms/step - loss: 0.0300 - all: 0.9781 - varroa: 0.9457 - pollen: 0.9708 - wasps: 0.9998 - cooling: 0.9960 - val_loss: 0.2041 - val_all: 0.9382 - val_varroa: 0.8740 - val_pollen: 0.9086 - val_wasps: 0.9971 - val_cooling: 0.9730
# Epoch 8/20
# 180/180 [==============================] - 7s 41ms/step - loss: 0.0236 - all: 0.9826 - varroa: 0.9559 - pollen: 0.9780 - wasps: 0.9998 - cooling: 0.9969 - val_loss: 0.1959 - val_all: 0.9460 - val_varroa: 0.8711 - val_pollen: 0.9291 - val_wasps: 0.9971 - val_cooling: 0.9867
# Epoch 9/20
# 180/180 [==============================] - 7s 42ms/step - loss: 0.0222 - all: 0.9836 - varroa: 0.9566 - pollen: 0.9797 - wasps: 0.9991 - cooling: 0.9988 - val_loss: 0.2868 - val_all: 0.9399 - val_varroa: 0.8652 - val_pollen: 0.9164 - val_wasps: 0.9932 - val_cooling: 0.9848
# Epoch 10/20
# 180/180 [==============================] - 7s 41ms/step - loss: 0.0221 - all: 0.9854 - varroa: 0.9649 - pollen: 0.9802 - wasps: 0.9991 - cooling: 0.9974 - val_loss: 0.2279 - val_all: 0.9438 - val_varroa: 0.8730 - val_pollen: 0.9232 - val_wasps: 0.9941 - val_cooling: 0.9848
# Epoch 11/20
# 180/180 [==============================] - 7s 40ms/step - loss: 0.0174 - all: 0.9882 - varroa: 0.9696 - pollen: 0.9854 - wasps: 0.9995 - cooling: 0.9981 - val_loss: 0.2334 - val_all: 0.9434 - val_varroa: 0.8793 - val_pollen: 0.9174 - val_wasps: 0.9971 - val_cooling: 0.9799
# Epoch 12/20
# 180/180 [==============================] - 7s 40ms/step - loss: 0.0165 - all: 0.9871 - varroa: 0.9661 - pollen: 0.9840 - wasps: 1.0000 - cooling: 0.9981 - val_loss: 3.5173 - val_all: 0.8769 - val_varroa: 0.8271 - val_pollen: 0.8508 - val_wasps: 0.9779 - val_cooling: 0.8518
# Epoch 13/20
# 180/180 [==============================] - 7s 40ms/step - loss: 0.1415 - all: 0.9534 - varroa: 0.9047 - pollen: 0.9398 - wasps: 0.9964 - cooling: 0.9729 - val_loss: 0.3829 - val_all: 0.9271 - val_varroa: 0.8643 - val_pollen: 0.9242 - val_wasps: 0.9854 - val_cooling: 0.9344
# Epoch 14/20
# 180/180 [==============================] - 7s 41ms/step - loss: 0.0678 - all: 0.9652 - varroa: 0.9241 - pollen: 0.9564 - wasps: 0.9960 - cooling: 0.9842 - val_loss: 0.2196 - val_all: 0.9394 - val_varroa: 0.8691 - val_pollen: 0.9223 - val_wasps: 0.9961 - val_cooling: 0.9701
# Epoch 15/20
# 180/180 [==============================] - 7s 40ms/step - loss: 0.0177 - all: 0.9875 - varroa: 0.9682 - pollen: 0.9849 - wasps: 0.9997 - cooling: 0.9974 - val_loss: 0.2450 - val_all: 0.9423 - val_varroa: 0.8779 - val_pollen: 0.9174 - val_wasps: 0.9971 - val_cooling: 0.9770
# Epoch 16/20
# 180/180 [==============================] - 7s 41ms/step - loss: 0.0107 - all: 0.9913 - varroa: 0.9745 - pollen: 0.9911 - wasps: 0.9998 - cooling: 0.9997 - val_loss: 0.2612 - val_all: 0.9417 - val_varroa: 0.8844 - val_pollen: 0.9193 - val_wasps: 0.9980 - val_cooling: 0.9652
# Epoch 17/20
# 180/180 [==============================] - 7s 40ms/step - loss: 0.0093 - all: 0.9933 - varroa: 0.9793 - pollen: 0.9948 - wasps: 1.0000 - cooling: 0.9990 - val_loss: 0.2990 - val_all: 0.9460 - val_varroa: 0.8857 - val_pollen: 0.9271 - val_wasps: 0.9971 - val_cooling: 0.9740
# Epoch 18/20
# 180/180 [==============================] - 7s 41ms/step - loss: 0.0091 - all: 0.9934 - varroa: 0.9811 - pollen: 0.9929 - wasps: 1.0000 - cooling: 0.9995 - val_loss: 0.2732 - val_all: 0.9477 - val_varroa: 0.8857 - val_pollen: 0.9271 - val_wasps: 0.9961 - val_cooling: 0.9818
# Epoch 19/20
# 180/180 [==============================] - 7s 40ms/step - loss: 0.0089 - all: 0.9934 - varroa: 0.9814 - pollen: 0.9932 - wasps: 0.9998 - cooling: 0.9991 - val_loss: 0.2908 - val_all: 0.9455 - val_varroa: 0.8789 - val_pollen: 0.9223 - val_wasps: 0.9980 - val_cooling: 0.9828
# Epoch 20/20
# 180/180 [==============================] - 7s 41ms/step - loss: 0.0058 - all: 0.9961 - varroa: 0.9884 - pollen: 0.9964 - wasps: 1.0000 - cooling: 0.9998 - val_loss: 0.2819 - val_all: 0.9453 - val_varroa: 0.8906 - val_pollen: 0.9154 - val_wasps: 0.9971 - val_cooling: 0.9779

# %%
# !tensorboard dev upload --logdir ./tensorflow_hub/ \
  --name "model" \
  --description "dropout layer 0.33" \
  --one_shot
# Out:
# New experiment created. View your TensorBoard at: https://tensorboard.dev/experiment/SQ0eUze4Qluyklr3KVJREQ/
#
# [2023-01-10T13:32:13] Started scanning logdir.
# [2023-01-10T13:32:17] Total uploaded: 1440 scalars, 0 tensors, 4 binary objects (321.4 kB)
# [2023-01-10T13:32:17] Done scanning logdir.
#
#
# Done. View your TensorBoard at https://tensorboard.dev/experiment/SQ0eUze4Qluyklr3KVJREQ/

# %%
model.evaluate(test_images, test_labels)
# Out:
# 24/24 [==============================] - 1s 15ms/step - loss: 0.3077 - all: 0.9502 - varroa: 0.8952 - pollen: 0.9395 - wasps: 0.9935 - cooling: 0.9727
# [0.3076629340648651,
#  0.9502203464508057,
#  0.8952323794364929,
#  0.9395031929016113,
#  0.9934895634651184,
#  0.97265625]

# %%
x = test_images[555]
plt.imshow(x)

# %%
model.predict(x.reshape(1,300,150,3)), test_labels[555]

# %%
x = test_images[144]
plt.imshow(x)

# %%
model.predict(x.reshape(1,300,150,3)), test_labels[144]
